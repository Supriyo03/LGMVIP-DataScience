# %% [markdown]
# <a href="https://colab.research.google.com/github/Supriyo03/LGMVIP-DataScience/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import pandas as pd
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img=io.imread("https://post.medicalnewstoday.com/wp-content/uploads/sites/3/2020/02/322868_1100-800x825.jpg")
plt.imshow(img[:,:,::-1])
plt.axis(False)
plt.show()

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
invert_img=cv2.bitwise_not(grey_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=800x825 at 0x7F6581BAFF90>

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)
invblur_img=cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=800x825 at 0x7F6581C18A10>

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=800x825 at 0x7F6581C0CF90>

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
